# %%
from dotenv import load_dotenv
import os

from src.embeddings import get_embedding

vec = get_embedding("frankfurts in Barcelona")

len(vec), vec[:5]
# Out:
# (1536,
#  [-0.0470806360244751,
#   0.0029127993620932102,
#   -0.007305615581572056,
#   -0.017690226435661316,
#   0.009593868628144264])

# %%
import numpy as np
from src.embeddings import get_embedding
from sklearn.metrics.pairwise import cosine_similarity

# 1. Your evaluation dataset
texts = [
    "Burgers restaurants",
    "Hotdog restaurants",
    "Fast food restaurants",
    "Gourmet burger restaurants",
    "Event agencies",
    "Corporate event planners",
    "Email marketing SaaS for ecommerce",
    "CRM software for ecommerce",
    "Dentists",
    "Dental clinics",
    "Physiotherapy clinics",
    "Cybersecurity consulting companies",
    "Managed IT services",
    "Cloud consulting agencies",
    "Yoga studios",
    "Pilates studios",
    "Gyms and fitness centers",
    "Clothing stores",
    "Shoe stores",
    "Sports stores"
]

print("Embedding all items...")
embeddings = [get_embedding(t) for t in texts]

# 2. Compute similarities for each text
for i, text in enumerate(texts):
    sims = []
    for j, other in enumerate(texts):
        if i == j: 
            continue
        sim = cosine_similarity([embeddings[i]], [embeddings[j]])[0][0]
        sims.append((other, sim))

    # Sort by similarity descending
    sims.sort(key=lambda x: x[1], reverse=True)
    top3 = sims[:3]

    print("\n---")
    print(f"TEXT: {text}")
    print("Top 3 matches:")
    for t, s in top3:
        print(f"  → {t}  (score: {s:.3f})")
# Out:
# Embedding all items...
#
# ---
# TEXT: Burgers restaurants
# Top 3 matches:
#   → Gourmet burger restaurants  (score: 0.732)
#   → Hotdog restaurants  (score: 0.635)
#   → Fast food restaurants  (score: 0.620)
#
# ---
# TEXT: Hotdog restaurants
# Top 3 matches:
#   → Burgers restaurants  (score: 0.635)
#   → Gourmet burger restaurants  (score: 0.615)
#   → Fast food restaurants  (score: 0.581)
#
# ---
# TEXT: Fast food restaurants
# Top 3 matches:
#   → Burgers restaurants  (score: 0.620)
#   → Hotdog restaurants  (score: 0.581)
#   → Gourmet burger restaurants  (score: 0.546)
#
# ---
# TEXT: Gourmet burger restaurants
# Top 3 matches:
#   → Burgers restaurants  (score: 0.732)
#   → Hotdog restaurants  (score: 0.615)
#   → Fast food restaurants  (score: 0.546)
#
# ---
# TEXT: Event agencies
# Top 3 matches:
#   → Corporate event planners  (score: 0.665)
#   → Cloud consulting agencies  (score: 0.465)
#   → Cybersecurity consulting companies  (score: 0.325)
#
# ---
# TEXT: Corporate event planners
# Top 3 matches:
#   → Event agencies  (score: 0.665)
#   → Cloud consulting agencies  (score: 0.419)
#   → Cybersecurity consulting companies  (score: 0.357)
#
# ---
# TEXT: Email marketing SaaS for ecommerce
# Top 3 matches:
#   → CRM software for ecommerce  (score: 0.746)
#   → Cloud consulting agencies  (score: 0.346)
#   → Managed IT services  (score: 0.344)
#
# ---
# TEXT: CRM software for ecommerce
# Top 3 matches:
#   → Email marketing SaaS for ecommerce  (score: 0.746)
#   → Cloud consulting agencies  (score: 0.421)
#   → Managed IT services  (score: 0.314)
#
# ---
# TEXT: Dentists
# Top 3 matches:
#   → Dental clinics  (score: 0.698)
#   → Fast food restaurants  (score: 0.332)
#   → Burgers restaurants  (score: 0.332)
#
# ---
# TEXT: Dental clinics
# Top 3 matches:
#   → Dentists  (score: 0.698)
#   → Physiotherapy clinics  (score: 0.536)
#   → Yoga studios  (score: 0.348)
#
# ---
# TEXT: Physiotherapy clinics
# Top 3 matches:
#   → Dental clinics  (score: 0.536)
#   → Pilates studios  (score: 0.520)
#   → Yoga studios  (score: 0.464)
#
# ---
# TEXT: Cybersecurity consulting companies
# Top 3 matches:
#   → Cloud consulting agencies  (score: 0.691)
#   → Managed IT services  (score: 0.479)
#   → Corporate event planners  (score: 0.357)
#
# ---
# TEXT: Managed IT services
# Top 3 matches:
#   → Cloud consulting agencies  (score: 0.552)
#   → Cybersecurity consulting companies  (score: 0.479)
#   → Email marketing SaaS for ecommerce  (score: 0.344)
#
# ---
# TEXT: Cloud consulting agencies
# Top 3 matches:
#   → Cybersecurity consulting companies  (score: 0.691)
#   → Managed IT services  (score: 0.552)
#   → Event agencies  (score: 0.465)
#
# ---
# TEXT: Yoga studios
# Top 3 matches:
#   → Pilates studios  (score: 0.742)
#   → Gyms and fitness centers  (score: 0.488)
#   → Physiotherapy clinics  (score: 0.464)
#
# ---
# TEXT: Pilates studios
# Top 3 matches:
#   → Yoga studios  (score: 0.742)
#   → Physiotherapy clinics  (score: 0.520)
#   → Gyms and fitness centers  (score: 0.479)
#
# ---
# TEXT: Gyms and fitness centers
# Top 3 matches:
#   → Yoga studios  (score: 0.488)
#   → Pilates studios  (score: 0.479)
#   → Sports stores  (score: 0.463)
#
# ---
# TEXT: Clothing stores
# Top 3 matches:
#   → Shoe stores  (score: 0.691)
#   → Sports stores  (score: 0.676)
#   → Yoga studios  (score: 0.357)
#
# ---
# TEXT: Shoe stores
# Top 3 matches:
#   → Clothing stores  (score: 0.691)
#   → Sports stores  (score: 0.671)
#   → Fast food restaurants  (score: 0.382)
#
# ---
# TEXT: Sports stores
# Top 3 matches:
#   → Clothing stores  (score: 0.676)
#   → Shoe stores  (score: 0.671)
#   → Gyms and fitness centers  (score: 0.463)
